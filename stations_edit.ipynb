# %%
import pandas as pd
df_stations_again = pd.read_csv('stations_again.csv')

# Direction:
df_stations_again[df_stations_again.direction == 'North'].count()
#     North - 112
df_stations_again[df_stations_again.direction == 'South'].count()
#     South - 206
df_stations_again[df_stations_again.direction == 'East'].count()
#     East - 124
df_stations_again[df_stations_again.direction == 'West'].count()
#     West - 159
df_stations_again[df_stations_again.direction == 'Central'].count()
#     Central - 53
df_stations_again.loc[df_stations_again['direction'].isin(['North','South','East','West','Central'])]
#     Total - 654

# Borough:
df_stations_again[df_stations_again.borough == 'Barking and Dagenham'].count()
#     Barking and Dagenham - 4
df_stations_again[df_stations_again.borough == 'Barnet'].count()
#     Barnet - 3
df_stations_again[df_stations_again.borough == 'Berkshire'].count()
#     Berkshire - 6
df_stations_again[df_stations_again.borough == 'Bexley'].count()
#     Bexley - 6
df_stations_again[df_stations_again.borough == 'Brent'].count()
#     Brent - 5
df_stations_again[df_stations_again.borough == 'Bromley'].count()
#     Tower Hamlets - 25
df_stations_again[df_stations_again.borough == 'Buckinghamshire'].count()
#     Buckinghamshire - 1
df_stations_again[df_stations_again.borough == 'Camden'].count()
#     Camden - 9
df_stations_again[df_stations_again.borough == 'Chelmsford'].count()
#     Chelmsford - 4
df_stations_again[df_stations_again.borough == 'City of London'].count()
#     City of London - 12
df_stations_again[df_stations_again.borough == 'Croydon'].count()
#     Croydon - 46
df_stations_again[df_stations_again.borough == 'Dartford'].count()
#     Dartford - 5
df_stations_again[df_stations_again.borough == 'Ealing'].count()
#     Ealing - 19
df_stations_again[df_stations_again.borough == 'Enfield'].count()
#     Enfield - 23
df_stations_again[df_stations_again.borough == 'Greenwich'].count()
#     Greenwich - 10
df_stations_again[df_stations_again.borough == 'Harringay'].count()
#     Harrigay - 3
df_stations_again[df_stations_again.borough == 'Hammersmith and Fulham'].count()
#     Hammersmith and Fulham - 3
df_stations_again[df_stations_again.borough == 'Hackney'].count()
#     Hackney - 12
df_stations_again[df_stations_again.borough == 'Harrow'].count()
#     Harrow - 12
df_stations_again[df_stations_again.borough == 'Havering'].count()
#     Havering - 15
df_stations_again[df_stations_again.borough == 'Hertfordshire'].count()
#     Hertfordshire - 9
df_stations_again[df_stations_again.borough == 'Hillingdon'].count()
#     Hillingdon - 11
df_stations_again[df_stations_again.borough == 'Hounslow'].count()
#     Hounslow - 3
df_stations_again[df_stations_again.borough == 'Islington'].count()
#     Islington - 9
df_stations_again[df_stations_again.borough == 'Kensington and Chelsea'].count()
#     Kensington and Chelsea - 2
df_stations_again[df_stations_again.borough == 'Kingston upon Thames'].count()
#     Kingston upon Thames - 22
df_stations_again[df_stations_again.borough == 'Lambeth'].count()
#     Lambeth - 11
df_stations_again[df_stations_again.borough == 'Lewisham'].count()
#     Lewisham - 14
df_stations_again[df_stations_again.borough == 'Merton'].count()
#     Merton - 13
df_stations_again[df_stations_again.borough == 'Newham'].count()
#     Newham - 5
df_stations_again[df_stations_again.borough == 'Redbridge'].count()
#     Redbridge - 7
df_stations_again[df_stations_again.borough == 'Reigate and Banstead'].count()
#     Reigate and Banstead - 1
df_stations_again[df_stations_again.borough == 'Richmond upon Thames'].count()
#     Richmond upon Thames - 26
df_stations_again[df_stations_again.borough == 'Southwark'].count()
#     Southwark - 6
df_stations_again[df_stations_again.borough == 'Sutton'].count()
#     Sutton - 11
df_stations_again[df_stations_again.borough == 'Tower Hamlets'].count()
#     Tower Hamlets - 13
df_stations_again[df_stations_again.borough == 'Waltham Forest'].count()
#     Waltham Forest - 6
df_stations_again[df_stations_again.borough == 'Wandsworth'].count()
#     Wandsworth - 16
df_stations_again[df_stations_again.borough == 'Westminster'].count()
#     Westminster - 11
# Out:
# station_identity    32
# station_deletion    32
# station             32
# latitude            32
# longitude           32
# zone                32
# postcode            32
# area                32
# borough             32
# direction           32
# dtype: int64

# %%
import pandas as pd
cwd = os.getcwd()
# df = pd.read_csv(cwd + '/files/scores.csv')
# df['pool'] = False
# df
list(df)
# # meals_list = ['True']
# # filtered_values = df.loc[(
# #         df['meals'].astype(str).isin(meals_list)
# #     )]
# # # df2 = df.loc[df['meals'] == True]
# # filtered_values
# # df['pet']=False
# # df['quiz']=False
# # df['lively']=False
# # df['rating']=0
df2 = df[['review_identity',
 'review_deletion',
 'pub_identity',
 'visit',
 'star',
 'atmosphere',
 'cleanliness',
 'clientele',
 'decor',
 'entertainment',
 'food',
 'friendliness',
 'opening',
 'price',
 'selection',
 'rating',
 'reviewer',
 'pet',
 'tv',
 'garden',
 'music',
 'late',
 'meals',
 'toilet',
 'cheap',
 'games',
 'quiz',
 'pool',
 'lively']]
# df2
df2.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')
df2
# Out:
#                          review_identity review_deletion  \
# 0   1869bc0d-e2a8-40c9-bcba-073bfaaa4ba0           False
# 1   e1c5fd3e-8fb3-40ff-a7cb-1bf2d20e8611           False
# 2   90ccf461-1a45-48ee-b8e2-9270e36393e4           False
# 3   f2df2681-9b63-46a7-83f2-1fb8d6e3e0a1           False
# 4   50fa15ac-5cd3-41ab-a183-54e52897955a           False
# ..                                   ...             ...
# 72  c44e9e14-ff8b-4a5c-b633-d4e040aa8362           False
# 73  21bf8d65-522f-4309-a018-ac4321ea303a           False
# 74  f3aea85b-1bd9-46d1-80a5-40afd9015996           False
# 75  feb58162-e0fc-42f6-8152-2b76934cafee           False
# 76  259949ed-f608-42d5-908f-b2f4b1d5e723           False
#
#                             pub_identity           visit           star  \
# 0   00ffd490-b3b8-424d-b5d2-5122bbebdba2       test date          decor
# 1   10f611a2-512f-4b07-aa57-8de878ccbb3b       test date          decor
# ...

# %%
df_boroughs = pd.DataFrame(df_stations_again['borough'].unique())
# df_boroughs
df.groupby(['col5', 'col2']).size()

# %%
df2.rename(columns={'rating': 'cheap'}, inplace=True)
df2.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')
df2
# Out:
# /var/folders/cw/sq91_wk16x98gmpdhs2gdfr80000gn/T/ipykernel_24205/1430772326.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'rating': 'cheap'}, inplace=True)
#                          review_identity  \
# 0   1869bc0d-e2a8-40c9-bcba-073bfaaa4ba0
# 1   e1c5fd3e-8fb3-40ff-a7cb-1bf2d20e8611
# 2   90ccf461-1a45-48ee-b8e2-9270e36393e4
# 3   f2df2681-9b63-46a7-83f2-1fb8d6e3e0a1
# 4   50fa15ac-5cd3-41ab-a183-54e52897955a
# ..                                   ...
# 77  b29bc273-e905-4d33-addf-25b0a9ff9b41
# 78  8e59a64f-684d-44b2-8554-dd968e9465ed
# 79                                   NaN
# 80                                   NaN
# 81                                   NaN
#
#                             pub_identity review_deletion                visit  \
# ...

# %%
import os
import uuid
import pandas as pd
cwd = os.getcwd()
# df = pd.read_csv(cwd + '/files/scores.csv')
# df.loc[df['pub_identity'] == '866ef4d9-669f-4bab-ade2-1af9da1a0065', 'review_identity'] = uuid.uuid4()
# df
# list(df)
# df['pool']=False
# df2 = df[['review_identity',
#  'review_deletion',
#  'pub_identity',
#  'visit',
#  'star',
#  'atmosphere',
#  'cleanliness',
#  'clientele',
#  'decor',
#  'entertainment',
#  'food',
#  'friendliness',
#  'opening',
#  'price',
#  'selection',
#  'reviewer',
#  'rating',
#  'pet',
#  'tv',
#  'garden',
#  'music',
#  'late',
#  'meals',
#  'toilets',
#  'cheap',
#  'games',
#  'quiz',
#  'pool',
#  'lively']]
# df.rename(columns={'toilet': 'toilets'}, inplace=True)
# df2
df.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')

# %%
['review_identity',
 '                     pub_identity',
 '                        review_deletion',
 'visit',
 '    star',
 ' atmosphere',
 'cleanliness',
 'clientele',
 'decor',
 'entertainment',
 'food',
 'friendliness',
 'opening',
 'price',
 'selection',
 'reviewer',
 'rating',
 'pet',
 '  tv',
 '   garden',
 'music',
 'late',
 ' meals',
 'toilets',
 'cheap',
 'games',
 'quiz',
 ' pool',
 ' lively']

# %%
# df_stations['borough'] = np.where(df_stations['area'] == 'Clapham', 'Wandsworth', df_stations['area'])
import pandas as pd
cwd = os.getcwd()
# df = pd.read_csv(cwd + '/files/photos.csv')
# df = df.drop('name', axis=1)
df_photos = pd.read_csv(cwd + '/files/photos.csv')
df_new = pd.DataFrame([('fcbe640b-1bae-4c6c-8e9e-987bdc8a9cd0', uuid.uuid4(), False)], columns=['pub_identity', 'photo_identity', 'photo_deletion'])
df = pd.concat([df_photos, df_new], ignore_index=True)
df
# Out:
#                             pub_identity  \
# 0   00ffd490-b3b8-424d-b5d2-5122bbebdba2
# 1   10f611a2-512f-4b07-aa57-8de878ccbb3b
# 2   7f3d8913-5a6d-40a4-a3e4-cd6eb0b0b8bf
# 3   0d3af39b-2da5-4ce4-bb58-734a1523af77
# 4   b9f3cbd8-2466-4652-9158-0d8a432bc1e7
# ..                                   ...
# 84  15902683-9de7-4f30-b844-0d3afa2f8490
# 85  7ce45ed3-0ba2-4fd7-a5cc-0aaca8ebf2f5
# 86  147bd112-05ca-47ad-b39c-439acdbda4b9
# 87  525edbdd-8eda-46f4-800d-013076d66f7f
# 88  fcbe640b-1bae-4c6c-8e9e-987bdc8a9cd0
#
#                           photo_identity  photo_deletion
# 0   ad340446-f5a3-475e-8af1-8218b8dfe54c           False
# 1   2cd0125d-a347-49dc-a2e0-b15e7cbe4c63           False
# 2   01a0c2e2-e1ee-46f1-9af1-7dd61e66e80f           False
# 3   7258c33d-54a1-4398-a795-05c40060fbd4           False
# 4   cc7d4931-3eaf-48ab-8585-68a4bd2e3f62           False
# ..                                   ...             ...
# 84  29a62963-dfd3-4fd8-a817-d3ec47d13fe7           False
# ...

# %%
df.to_csv(cwd + '/files/photos.csv', index=False, sep=',', encoding='utf-8')

# %%
import os
import uuid
import pandas as pd
cwd = os.getcwd()
# venues = pd.read_csv(cwd + '/files/venues.csv')
areas = pd.read_csv(cwd + '/files/areas.csv')
# areas.sort_values(by=['area'])

                          
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Battersea', 'type':'area', 'latitude':'51.4722', 'longitude':'-0.1655', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Brixton', 'type':'area', 'latitude':'51.4613', 'longitude':'-0.1156', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Hampstead', 'type':'area', 'latitude':'51.5556', 'longitude':'-0.1762', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Putney', 'type':'area', 'latitude':'51.4596', 'longitude':'-0.2141', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Stratford', 'type':'area', 'latitude':'51.5426', 'longitude':'-0.0010', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Twickenham', 'type':'area', 'latitude':'51.4453', 'longitude':'-0.3375', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Woodford', 'type':'area', 'latitude':'51.6042', 'longitude':'0.0325', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Alexandra Palace', 'type':'area', 'latitude':'51.5941', 'longitude':'-0.1298', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Bow', 'type':'area', 'latitude':'51.5321', 'longitude':'-0.0308', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Balham', 'type':'area', 'latitude':'51.4440', 'longitude':'-0.1494', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Borough', 'type':'area', 'latitude':'51.4881', 'longitude':'-0.0763', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Dulwich', 'type':'area', 'latitude':'51.4433', 'longitude':'-0.0676', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Hoxton', 'type':'area', 'latitude':'51.5311', 'longitude':'-0.0866', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Greenwich', 'type':'area', 'latitude':'51.4934', 'longitude':'0.0098', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Leyton', 'type':'area', 'latitude':'51.5702', 'longitude':'-0.0147', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Kennington', 'type':'area', 'latitude':'51.4880', 'longitude':'-0.1119', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Notting Hill', 'type':'area', 'latitude':'51.5160', 'longitude':'-0.2090', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Richmond', 'type':'area', 'latitude':'51.4613', 'longitude':'-0.3037', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Stoke Newington', 'type':'area', 'latitude':'51.5612', 'longitude':'-0.0835', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Spitalfields', 'type':'area', 'latitude':'51.5189', 'longitude':'-0.0748', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Streatham', 'type':'area', 'latitude':'51.4307', 'longitude':'-0.1295', 'parent_identity': '0'}
# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Tooting', 'type':'area', 'latitude':'51.4282', 'longitude':'-0.1669', 'parent_identity': '0'}
new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Wimbleon', 'type':'area', 'latitude':'51.4183', 'longitude':'-0.2206', 'parent_identity': '0'}
areas = areas.append(new_row, ignore_index=True)
areas.to_csv(cwd + '/files/areas.csv', index=False, sep=',', encoding='utf-8')
areas.sort_values(by=['area'])
# Out:
# /var/folders/cw/sq91_wk16x98gmpdhs2gdfr80000gn/T/ipykernel_24205/410418677.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   areas = areas.append(new_row, ignore_index=True)
#                            area_identity  area_deletion                 area  \
# 36  4405ca8a-c2a0-4040-94c2-877f2b6ced1d          False     Alexandra Palace
# 38  5f526db5-a48e-4d34-b017-e6c833dbb57c          False               Balham
# 29  def450bf-c4cf-488e-9602-95a28f6d7020          False            Battersea
# 0   33869d87-05dc-4728-a03a-c94cbab80292          False            Belgravia
# 26  3765283d-ade4-45d8-b3fa-2121fc7776ad          False           Bermondsey
# 11  031970b0-c0f6-450a-8515-4129c30f3302          False        Bethnal Green
# 6   8d7a9d04-eea3-45d7-a17c-e5271cbc1fa4          False           Bloomsbury
# 39  973e12de-e093-438f-8878-6337a0555ee8          False              Borough
# ...

# %%
import uuid
areas.loc[areas['area'] == 'Tooting', 'photo_identity'] = uuid.uuid4()
areas.sort_values(by=['area'])
# Out:
#                            area_identity  area_deletion                 area  \
# 36  4405ca8a-c2a0-4040-94c2-877f2b6ced1d          False     Alexandra Palace
# 38  5f526db5-a48e-4d34-b017-e6c833dbb57c          False               Balham
# 29  def450bf-c4cf-488e-9602-95a28f6d7020          False            Battersea
# 0   33869d87-05dc-4728-a03a-c94cbab80292          False            Belgravia
# 26  3765283d-ade4-45d8-b3fa-2121fc7776ad          False           Bermondsey
# 11  031970b0-c0f6-450a-8515-4129c30f3302          False        Bethnal Green
# 6   8d7a9d04-eea3-45d7-a17c-e5271cbc1fa4          False           Bloomsbury
# 39  973e12de-e093-438f-8878-6337a0555ee8          False              Borough
# 37  bfd8e41d-0402-4aa5-9bdb-4382e3ec894e          False                  Bow
# 30  b6fba238-e15d-4046-add2-5cbd96c5213d          False              Brixton
# 14  8576a0cd-0b4d-4a85-ba3c-122360e7d5f8          False               Camden
# ...

# %%
# import numpy as np
# grouper = pd.merge(venues, scores, how="left", on="pub_identity")
# grouper.head(3)
new_pub = grouper[['pub_identity',
 'pub_deletion',
 'place',
 'name',
 'address',
 'latitude',
 'longitude',
 'category',
 'rank',
 'station_identity',
 'area_identity']]
new_pub.head(3)
# Out:
#                            pub_identity  pub_deletion  \
# 0  00ffd490-b3b8-424d-b5d2-5122bbebdba2         False
# 1  10f611a2-512f-4b07-aa57-8de878ccbb3b         False
# 2  7f3d8913-5a6d-40a4-a3e4-cd6eb0b0b8bf         False
#
#                          place           name  \
# 0  ChIJd9ZrglcDdkgRbfzaNDJlWWk  Katzenjammers
# 1  ChIJ03GSCloDdkgRe_s-p2vyvQA      The Shard
# 2  ChIJo15e1lkDdkgR-X84Yf2cA0s     The George
#
#                                              address   latitude  longitude  \
# 0  The Hop Exchange, 24 Southwark St, London SE1 ...  51.504873  -0.090954
# 1            32 London Bridge St, London SE1 9SG, UK  51.504300  -0.086370
# 2             75 Borough High St, London SE1 1NH, UK  51.504304  -0.090417
#
#   category  rank                      station_identity  \
# 0      bar   3.0  f5b94c64-beb5-4295-95a1-34fc1f5b5a8d
# 1      bar   4.0  f5b94c64-beb5-4295-95a1-34fc1f5b5a8d
# 2      bar   4.0  f5b94c64-beb5-4295-95a1-34fc1f5b5a8d
#
# ...

# %%
# scores = scores.drop('rank', axis=1)
scores.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')

# %%
areas = areas.rename({'phot_identity': 'photo_identity'}, axis=1)
areas
# Out:
#                            area_identity  area_deletion                 area  \
# 0   33869d87-05dc-4728-a03a-c94cbab80292          False            Belgravia
# 1   a8270094-1d5b-4558-a1d0-5be568497233          False       Shepherds Bush
# 2   632602fe-f847-4e12-9e03-31e3d22aa344          False              Mayfair
# 3   1676a419-f2d0-4bf4-a5ae-569fea25e991          False                 Soho
# 4   f25607ca-ec88-46dc-a1f3-b8dedd3e5ca3          False           Marleybone
# 5   8e74a1f3-b8fc-4986-a520-0884eb581cb7          False        Finsbury Park
# 6   8d7a9d04-eea3-45d7-a17c-e5271cbc1fa4          False           Bloomsbury
# 7   87fbc59f-9c44-4e78-b4b5-000ef3b4d559          False              Holborn
# 8   5dbbbdb9-3ab1-4a96-a0e9-edf4ca8bd52a          False        Covent Garden
# 9   87b4b121-bf17-44e7-805a-a860f9ee4b33          False           Farringdon
# 10  480fafaa-7b2b-4282-a14f-e226e0b20922          False           Shoreditch
# ...

# %%
import uuid, os
import pandas as pd
cwd = os.getcwd()
areas = pd.read_csv(cwd + '/files/areas.csv')
# areas['phot_identity'] = [uuid.uuid4() for _ in range(len(areas.index))]
# areas['position'] = 0
areas.loc[areas['area'] == 'Belgravia', 'position'] = 19
areas.loc[areas['area'] == 'Shepherds Bush', 'position'] = 12
areas.loc[areas['area'] == 'Mayfair', 'position'] = 13
areas.loc[areas['area'] == 'Soho', 'position'] = 20
areas.loc[areas['area'] == 'Marleybone', 'position'] = 6
areas.loc[areas['area'] == 'Finsbury Park', 'position'] = 2
areas.loc[areas['area'] == 'Bloomsbury', 'position'] = 14
areas.loc[areas['area'] == 'Holborn', 'position'] = 15
areas.loc[areas['area'] == 'Covent Garden', 'position'] = 26
areas.loc[areas['area'] == 'Farringdon', 'position'] = 21
areas.loc[areas['area'] == 'Shoreditch', 'position'] = 16
areas.loc[areas['area'] == 'Bethnal Green', 'position'] = 23
areas.loc[areas['area'] == 'Walthamstow', 'position'] = 4
areas.loc[areas['area'] == 'City', 'position'] = 28
areas.loc[areas['area'] == 'Camden', 'position'] = 7
areas.loc[areas['area'] == 'Hackney', 'position'] = 10
areas.loc[areas['area'] == 'South Bank', 'position'] = 27
areas.loc[areas['area'] == 'Rickmansworth', 'position'] = 0
areas.loc[areas['area'] == 'Hammersmith', 'position'] = 18
areas.loc[areas['area'] == 'Loughton', 'position'] = 5
areas.loc[areas['area'] == 'Islington', 'position'] = 8
areas.loc[areas['area'] == 'Rotherhithe', 'position'] = 36
areas.loc[areas['area'] == 'Wapping', 'position'] = 29
areas.loc[areas['area'] == 'Elephant and Castle', 'position'] = 25
areas.loc[areas['area'] == 'Dalston', 'position'] = 9
areas.loc[areas['area'] == 'Clapton', 'position'] = 3
areas.loc[areas['area'] == 'Bermondsey', 'position'] = 14
areas.loc[areas['area'] == 'London Bridge', 'position'] = 22
areas.loc[areas['area'] == 'Clapham', 'position'] = 32
areas.loc[areas['area'] == 'Battersea', 'position'] = 31
areas.loc[areas['area'] == 'Brixton', 'position'] = 33
areas.loc[areas['area'] == 'Hampstead', 'position'] = 1
areas.loc[areas['area'] == 'Putney', 'position'] = 24
areas.loc[areas['area'] == 'Stratford', 'position'] = 17
areas.loc[areas['area'] == 'Twickenham', 'position'] = 30
areas.loc[areas['area'] == 'Woodford', 'position'] = 11
areas
# Out:
#                            area_identity  area_deletion                 area  \
# 0   33869d87-05dc-4728-a03a-c94cbab80292          False            Belgravia
# 1   a8270094-1d5b-4558-a1d0-5be568497233          False       Shepherds Bush
# 2   632602fe-f847-4e12-9e03-31e3d22aa344          False              Mayfair
# 3   1676a419-f2d0-4bf4-a5ae-569fea25e991          False                 Soho
# 4   f25607ca-ec88-46dc-a1f3-b8dedd3e5ca3          False           Marleybone
# 5   8e74a1f3-b8fc-4986-a520-0884eb581cb7          False        Finsbury Park
# 6   8d7a9d04-eea3-45d7-a17c-e5271cbc1fa4          False           Bloomsbury
# 7   87fbc59f-9c44-4e78-b4b5-000ef3b4d559          False              Holborn
# 8   5dbbbdb9-3ab1-4a96-a0e9-edf4ca8bd52a          False        Covent Garden
# 9   87b4b121-bf17-44e7-805a-a860f9ee4b33          False           Farringdon
# 10  480fafaa-7b2b-4282-a14f-e226e0b20922          False           Shoreditch
# ...

# %%
# df_area.to_csv('area.csv', index=False)

import pandas as pd
import os
import uuid
cwd = os.getcwd()
# areas = pd.read_csv(cwd + '/files/areas.csv')
df_pubs = pd.read_csv(cwd + '/files/venues.csv')
df_areas = pd.read_csv(cwd + '/files/areas.csv')
df_stations = df_areas[['area_identity', 'area']]
pubs_area = pd.merge(df_pubs, df_stations, how='left', on='area_identity')
pubs_area

pub_id = 'c9a4f721-53ae-4482-916c-abc4e1ba52b1'
id_type = pubs_area.loc[pubs_area['pub_identity'] == pub_id, 'area'].iloc[0]
id_type
# pubs = pubs.drop('Unnamed: 0', axis=1)
# pubs['area_identity'] = " "
# df.to_csv(cwd + '/files/venues.csv', index=False)
# scores['tv'] = False
# scores['garden'] = False
# scores['music'] = False
# scores['late'] = False
# scores['meals'] = False
# scores['toilet'] = False
# scores['cheap'] = False
# scores['games'] = False

# pubs.loc[pubs['area_identity'] == '632602fe-f847-4e12-9e03-31e3d22aa344', 'area'] = 'Mayfair'

# new_row = {'area_identity':uuid.uuid4(), 'area_deletion':False, 'area':'Clapham', 'type':'area', 'latitude':51.45654, 'longitude':-0.13876, 'parent_identity':0}
# areas = areas.append(new_row, ignore_index=True)

# areas.loc[areas['area_identity'] == '480fafaa-7b2b-4282-a14f-e226e0b20922', 'latitude'] = 51.52383
# areas.loc[areas['area_identity'] == '480fafaa-7b2b-4282-a14f-e226e0b20922', 'longitude'] = -0.07545
# areas.loc[areas['area_identity'] == '480fafaa-7b2b-4282-a14f-e226e0b20922', 'area'] = 'Shoreditch'
# scores = scores.drop('clean', axis=1)
# df = df.drop('_is_copy', axis=1)
# df = df.drop('_mgr', axis=1)
# df = df.drop('_item_cache', axis=1)
# df = df.drop('_attrs', axis=1)
# df = df.drop('_flags', axis=1)

# areas = areas.drop(areas[areas.area_identity == '07139d67-7e99-47b7-860b-04cead639a3c'].index)
# df.to_csv(cwd + '/files/venues.csv', index=False, sep=',', encoding='utf-8')
# areas.sort_values(by='area')
# df = pd.merge
# Out:
# 'Walthamstow'

# %%
areas.to_csv(cwd + '/files/areas.csv', index=False, sep=',', encoding='utf-8')

# %%
cwd = os.getcwd()
pubs_df.to_csv(cwd + '/files/pubs.csv', index=False, sep=',', encoding='utf-8')

# %%
import numpy as np
df = pd.read_csv(cwd + '/files/scores.csv')
df['rating'] = (df[["atmosphere", "clientele", "decor", "friendliness", "selection"]]).mean(axis=1) * 10
df['rank'] = np.where(df['rating']>80,5,np.where(df['rating']>60,4,np.where(df['rating']>40,3,np.where(df['rating']>20,2,np.where(df['rating']>0,1,0)))))
df[["atmosphere", "clientele", "decor", "friendliness", "selection", "rating", "rank"]].sort_values(by='rank', ascending=False)
df.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')

# %%
# df = pd.read_csv(cwd + '/files/venues.csv')
# df[['pub_identity', 'name']]
# import uuid
# df2['photo_identity'] = [uuid.uuid4() for _ in range(len(df_area.index))]
# df_area
# df
# cwd = os.getcwd()
# df2.to_csv(cwd + '/files/scores.csv', index=False, sep=',', encoding='utf-8')
# df['photo_identity'] = [uuid.uuid4() for _ in range(len(df.index))]
# df_photo = df[['pub_identity', 'name']]
# df_photo['photo_identity'] = [uuid.uuid4() for _ in range(len(df.index))]
# df_photo['photo_deletion'] = False
list(df_photo)
df_photo[['photo_identity', 'photo_deletion', 'name', 'pub_identity']]
df_photo.to_csv(cwd + '/files/photos.csv', index=False, sep=',', encoding='utf-8')

# %%
import numpy as np
import pandas as pd
import os
cwd = os.getcwd()
df1 = pd.read_csv(cwd + '/files/venues.csv')
df2 = pd.read_csv(cwd + '/files/scores.csv')
df = pd.merge(df1,df2,on=['pub_identity'],how="inner",indicator=True)
# filtered_values = np.where((df['tv'] == True) & (df['garden'] == False))
filtered_values = df.loc[(df['tv'].astype(str) == 'False') & (df['garden'].astype(str) == 'True') & (df['music'].astype(str) == 'False')]
# df3 = df.loc[df['meals'] == True]
filtered_values
# Out:
#                             pub_identity  pub_deletion  \
# 69  68196501-34c4-4a4c-b4e4-9ac7d7dc48d6         False
# 70  7b6e05c3-f6ca-4d6f-85d5-98ce06d82fb2         False
# 76  07b38ff8-cbde-4e21-b2ba-9b30f8d84b52         False
#
#                           place                  name  \
# 69  ChIJKylYzmQbdkgRRFvGMVFMWKg  The Hen and Chickens
# 70  ChIJOURKcHwFdkgRqfDY5N2gv6Y  Windmill Pub Clapham
# 76  ChIJHR4pfPgcdkgRZRSlOZj1q4A      The Clapton Hart
#
#                                               address   latitude  longitude  \
# 69                109 St Paul's Rd, London N1 2NA, UK  51.546048  -0.101999
# 70      Clapham Common South Side, London SW4 9DE, UK  51.457617  -0.144196
# 76  231 Lower Clapton Rd, Lower Clapton, London E5...  51.557776  -0.056123
#
#    category  rank                      station_identity  ...     tv garden  \
# 69      bar   0.0  6339de91-7b07-4cc2-960f-3e12bb216599  ...  False   True
# ...

# %%
import datetime
from dateutil.relativedelta import relativedelta

# one_year_from_now = datetime.datetime.now()
# + relativedelta(years=1)
date_formated = datetime.datetime.now().strftime("%d/%m/%Y")
print(date_formated)
# Out:
# 17/04/2023

# %%
import os
import pandas as pd
cwd = os.getcwd()
# df.rename(columns={'toilets': 'favourite'}, inplace=True)

# df = pd.read_csv(cwd + '/files/pubs.csv')
# df.head(5)
# df = df.drop('food', axis=1)
# list(df)

# df.to_csv(cwd + '/files/pubs.csv', index=False, sep=',', encoding='utf-8')
# df2
# df['rank'].fillna(0)
# df['rank'].astype(int, errors='ignore')

# df['rank'] = df['rank'].astype(int).round(decimals = 0)
# df['rank']
# df.dtypes
# pd.set_option('display.max_rows', 25)
# df.sort_values(by='rank', ascending=False)

# df.to_csv(cwd + '/files/pubs.csv', index=False, sep=',', encoding='utf-8')
# df = pd.read_csv(cwd + '/files/pubs.csv')
# df.dtypes
df
# Out:
#                                           address  \
# 0         32 London Bridge St, London SE1 9SG, UK
# 1     29 Watling St, Greater, London EC4M 9BR, UK
# 2                  39 Bow St, London WC2E 7AU, UK
# 3         213 Strand, Temple, London WC2R 1AP, UK
# 4      91-92 Strand, Greater, London WC2R 0DW, UK
# ..                                            ...
# 805              57 Melina Rd, London W12 9HY, UK
# 806        114 Campden Hill Rd, London W8 7AR, UK
# 807                98 Park Rd, London NW1 4SH, UK
# 808            23 Francis St, London SW1P 1DN, UK
# 809  11 Warwick Way, Pimlico, London SW1V 1QT, UK
#
#                             area_identity category  \
# 0    75808b33-a6d6-4e79-bc63-cce0831d36a9      bar
# 1    71f589fb-f617-48b9-b779-dc1e8d73b1fe      bar
# 2    5dbbbdb9-3ab1-4a96-a0e9-edf4ca8bd52a      bar
# 3    87fbc59f-9c44-4e78-b4b5-000ef3b4d559      bar
# 4    5dbbbdb9-3ab1-4a96-a0e9-edf4ca8bd52a      bar
# ...

# %%
# df.rename(columns={'lively': 'historic'}, inplace=True)
# df.rename(columns={'games': 'darts'}, inplace=True)
# df.rename(columns={'toilets': 'favourite'}, inplace=True)
# list(df)
df = df[['review_identity',
 'review_deletion',
 'pub_identity',
 'tv',
 'garden',
 'meals',
 'music',
 'quiz',
 'pool',
 'darts',
 'cheap',
 'pet',
 'historic',
 'late',
 'favourite']]
df
# Out:
#                           review_identity review_deletion  \
# 0    1869bc0d-e2a8-40c9-bcba-073bfaaa4ba0           False
# 1    e1c5fd3e-8fb3-40ff-a7cb-1bf2d20e8611           False
# 2    f2df2681-9b63-46a7-83f2-1fb8d6e3e0a1           False
# 3    50fa15ac-5cd3-41ab-a183-54e52897955a           False
# 4    e55d062a-f75b-4d7e-95bb-2f7199650949           False
# ..                                    ...             ...
# 141  33ffbda2-5092-4c4a-8af5-85e4980390e5           False
# 142  7bc34c4b-64a4-4753-92db-bdad04ff7297           False
# 143  1cb5911f-0c62-4ef6-bdf4-3d77671b8044           False
# 144  08f270ad-e9b3-4bc3-afa2-6fb9d09cbdef           False
# 145  25782f5d-d153-47f0-abab-629d736b5635           False
#
#                              pub_identity     tv  garden  meals  music   quiz  \
# 0    00ffd490-b3b8-424d-b5d2-5122bbebdba2  False   False  False  False  False
# 1    10f611a2-512f-4b07-aa57-8de878ccbb3b  False   False   True  False  False
# ...

# %%
df.to_csv(cwd + '/files/reviews_new.csv', index=False, sep=',', encoding='utf-8')

# %%
import json
class Doc:
    def __init__(self):
        self.abc=Abc()
    def jsonable(self):
        return self.__dict__

def ComplexHandler(Obj):
    if hasattr(Obj, 'jsonable'):
        return Obj.jsonable()
    else:
        raise TypeError, 'Object of type %s with value of %s is not JSON serializable' % (type(Obj), repr(Obj))

doc=Doc()
print json.dumps(doc, default=ComplexHandler)
# Out:
#   Cell In[2], line 12
#     raise TypeError, 'Object of type %s with value of %s is not JSON serializable' % (type(Obj), repr(Obj))
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
pubs = pd.read_csv(

# %%
import json


class Doc:
    def __init__(self):
        self.identity=Identity()
        self.data="all data"
    def reprJSON(self):
        return dict(id=self.identity, data=self.data) 

class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if hasattr(obj,'reprJSON'):
            return obj.reprJSON()
        else:
            return json.JSONEncoder.default(self, obj)

doc=Doc()
print ("Str representation")
print (doc.reprJSON())
print ("Full JSON")
print (json.dumps(doc.reprJSON(), cls=ComplexEncoder))
print ("Partial JSON")
print (json.dumps(doc.identity.addr.reprJSON(), cls=ComplexEncoder))
# Out:
# Str representation
# {'id': <__main__.Identity object at 0x7fc4f0f0e160>, 'data': 'all data'}
# Full JSON
# {"id": {"name": "abc name", "firstname": "abc first", "address": {"street": "sesame street", "zip": "13000"}}, "data": "all data"}
# Partial JSON
# {"street": "sesame street", "zip": "13000"}
